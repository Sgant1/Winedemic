# %% [markdown]
# ### Import Dependencies

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
import os
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# # ----------------------------------------------------
# ### Load Data

# %%
file = 'converted_datatypes.csv'
df = pd.read_csv(file)
df
# Out:
#        Company Name    Ship Date  City  State  Shipping Service  Created Date  \
# 0                 1  43952.87139  1555     34                 5   43940.85348
# 1                 1  43952.87149  5113     44                 1   43943.52123
# 2                 1  43952.87149  1341      5                 9   43945.43794
# 3                 1  43952.87148  4881      4                 4   43945.60456
# 4                 1  43952.87148  4984     44                 1   43947.43795
# ...             ...          ...   ...    ...               ...           ...
# 32226             3  43977.58227  3588     29                 9   43976.69821
# 32227             3  43979.91545  4886      4                 9   43976.83360
# 32228             3  43981.48807  2038     14                 9   43979.78144
# 32229             3  43979.57612   225     10                 9   43973.85428
# 32230             3  43980.71198   225     10                 9   43973.85428
#
#        Weight  Item/Bottle Count
# 0        10.5                  3
# 1        20.2                  6
# 2        20.2                  6
# 3        10.5                  3
# 4        39.0                 12
# ...       ...                ...
# 32226    14.0                  4
# 32227    26.0                  7
# 32228    18.5                  5
# 32229    29.0                  8
# 32230    27.0                  4
#
# [32231 rows x 8 columns]

# %% [markdown]
# # ----------------------------------------------------
# ### Scale and Split Data

# %%
# split into features and target
X = df.drop(columns=['Item/Bottle Count', 'Weight'], axis=1)
y = df[['Item/Bottle Count', 'Weight']]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# scale the data
scaler = MinMaxScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # ----------------------------------------------------
# ### Build Neural Network Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.


def create_model(
    number_input_features, 
    hidden_nodes_layer1,
    hidden_nodes_layer2,
    hidden_nodes_layer3,
    hidden_nodes_layer4,
    hidden_nodes_layer5,
    activation_hidden,
    epochs
):
    model = tf.keras.models.Sequential()

    # First layer
    model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, 
                                 input_dim=number_input_features,
                                 activation=activation_hidden))

    # Second hidden layer
    model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, 
                                 activation=activation_hidden))

    # Third hidden layer
    model.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, 
                                 activation=activation_hidden))

    
    # Fourth hidden layer
    model.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, 
                                 activation=activation_hidden))
    
    # Fifth hidden layer
    model.add(tf.keras.layers.Dense(units=hidden_nodes_layer5, 
                                 activation=activation_hidden))
    
    # Output layer
    model.add(tf.keras.layers.Dense(units=1, 
                                 activation='relu'))

    # Check the structure of the model
    model.summary()

    # Compile the model
    model.compile(loss='binary_crossentropy',
               optimizer='adam',
               metrics=['accuracy'])

    # Train the model
    fit_model = model.fit(X_train_scaled,y_train,
                       epochs=epochs)

    # Evaluate the model using the test data
    model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test,verbose=2)
    print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %% [markdown]
# ### Run the Model

# %%
# edit model hyperparameters

create_model(
    number_input_features = 6,
    hidden_nodes_layer1 = 100,
    hidden_nodes_layer2 = 60,
    hidden_nodes_layer3 = 40,
    hidden_nodes_layer4 = 20,
    hidden_nodes_layer5 = 10,
    activation_hidden='relu',
    epochs=20
)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 100)               700
#
#  dense_31 (Dense)            (None, 60)                6060
#
#  dense_32 (Dense)            (None, 40)                2440
#
#  dense_33 (Dense)            (None, 20)                820
#
#  dense_34 (Dense)            (None, 10)                210
#
#  dense_35 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 10,241
# Trainable params: 10,241
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 756/756 [==============================] - 3s 2ms/step - loss: -144.1219 - accuracy: 0.1742
# Epoch 2/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6461 - accuracy: 0.1802
# Epoch 3/20
# 756/756 [==============================] - 2s 3ms/step - loss: -152.6462 - accuracy: 0.1802
# Epoch 4/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6462 - accuracy: 0.1802
# Epoch 5/20
# 756/756 [==============================] - 2s 3ms/step - loss: -152.6461 - accuracy: 0.1802
# Epoch 6/20
# 756/756 [==============================] - 2s 3ms/step - loss: -152.6463 - accuracy: 0.1802
# Epoch 7/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6462 - accuracy: 0.1802
# Epoch 8/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6462 - accuracy: 0.1802
# Epoch 9/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6461 - accuracy: 0.1802
# Epoch 10/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6463 - accuracy: 0.1802
# Epoch 11/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6463 - accuracy: 0.1802
# Epoch 12/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6462 - accuracy: 0.1802
# Epoch 13/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6462 - accuracy: 0.1802
# Epoch 14/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6462 - accuracy: 0.1802
# Epoch 15/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6462 - accuracy: 0.1802
# Epoch 16/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6463 - accuracy: 0.1802
# Epoch 17/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6462 - accuracy: 0.1802
# Epoch 18/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6463 - accuracy: 0.1802
# Epoch 19/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6462 - accuracy: 0.1802
# Epoch 20/20
# 756/756 [==============================] - 2s 2ms/step - loss: -152.6462 - accuracy: 0.1802
# 252/252 - 1s - loss: -1.5339e+02 - accuracy: 0.1791 - 503ms/epoch - 2ms/step
# Loss: -153.39073181152344, Accuracy: 0.17913874983787537

# %%
#Pandas library to create DataFrames
import pandas as pd
#NumPy library for converting data types
import numpy as np

# %%
winedemic_df = pd.read_csv("winedemic_complete.csv")

# %%
winedemic_df.head()
# Out:
#    Unnamed: 0 Company Name Ship Date State          City Created Date  \
# 0           0        Ecom3  11/19/19    PA      STEELTON   2019-11-18
# 1           1        Ecom3  11/15/19    FL  CORAL GABLES   2019-11-14
# 2           2        Ecom3  11/14/19    IL       CHICAGO   2019-11-13
# 3           3        Ecom3  11/15/19    NJ        Rumson   2019-11-14
# 4           4        Ecom3  11/14/19    MD      PASADENA   2019-11-13
#
#    Item/Bottle Count  Weight  Year  Month  Day  Population Lockdown Start  \
# 0                6.0    18.0  2019     11   18  12,801,989      3/23/2020
# 1               12.0    36.0  2019     11   14  21,477,737       4/1/2020
# 2                6.0    18.0  2019     11   13  12,671,821      3/20/2020
# 3               12.0    36.0  2019     11   14   8,882,190      3/21/2020
# 4                6.0    18.0  2019     11   13   6,045,680      3/12/2020
#
#   Initial Expected Lockdown End Phase 1 Re-Opening Start Political Alignment
# ...

# %%
year2019_df = winedemic_df[winedemic_df["Year"] == 2019]
year2019_df
# Out:
#         Unnamed: 0 Company Name  Ship Date State           City Created Date  \
# 0                0        Ecom3   11/19/19    PA       STEELTON   2019-11-18
# 1                1        Ecom3   11/15/19    FL   CORAL GABLES   2019-11-14
# 2                2        Ecom3   11/14/19    IL        CHICAGO   2019-11-13
# 3                3        Ecom3   11/15/19    NJ         Rumson   2019-11-14
# 4                4        Ecom3   11/14/19    MD       PASADENA   2019-11-13
# ...            ...          ...        ...   ...            ...          ...
# 162313        7146        Ecom1    1/20/20    NM           Mora   2019-12-24
# 162659        7492      Winery2    1/27/20    FL     Palm Beach   2019-06-17
# 163288        8121        Ecom3     2/7/20    CO   Breckenridge   2019-10-11
# 247556       92389      Winery1  6/23/2020    FL         Naples   2019-12-03
# 252434       97267      Winery1    7/10/20    MD  Silver Spring   2019-10-29
#
# ...

# %%
state = year2019_df["State"].unique()
state
# Out:
# array(['PA', 'FL', 'IL', 'NJ', 'MD', 'NY', 'AR', 'MI', 'TN', 'VA', 'NC',
#        'NH', 'MO', 'CT', 'MA', 'WI', 'MN', 'OH', 'TX', 'WV', 'CA', 'VT',
#        'WA', 'SC', 'IN', 'GA', 'OR', 'LA', 'AZ', 'NV', 'KS', 'MT', 'CO',
#        'IA', 'NM', 'NE', 'ID', 'ME', 'DC', 'HI', 'RI', 'WY', 'SD', 'ND',
#        'AK', 'DE', 'OK', 'AL', 'KY'], dtype=object)

# %%
year2019_df = year2019_df.set_index("State")
year2019_df
# Out:
#        Unnamed: 0 Company Name  Ship Date           City Created Date  \
# State
# PA              0        Ecom3   11/19/19       STEELTON   2019-11-18
# FL              1        Ecom3   11/15/19   CORAL GABLES   2019-11-14
# IL              2        Ecom3   11/14/19        CHICAGO   2019-11-13
# NJ              3        Ecom3   11/15/19         Rumson   2019-11-14
# MD              4        Ecom3   11/14/19       PASADENA   2019-11-13
# ...           ...          ...        ...            ...          ...
# NM           7146        Ecom1    1/20/20           Mora   2019-12-24
# FL           7492      Winery2    1/27/20     Palm Beach   2019-06-17
# CO           8121        Ecom3     2/7/20   Breckenridge   2019-10-11
# FL          92389      Winery1  6/23/2020         Naples   2019-12-03
# MD          97267      Winery1    7/10/20  Silver Spring   2019-10-29
#
#        Item/Bottle Count  Weight  Year  Month  Day  Population Lockdown Start  \
# State
# ...

# %%
# Calculate the total 2020 Item/Bottle Count.
total_count_2019 = year2019_df["Item/Bottle Count"].sum()
total_count_2019
# Out:
# 964068.0

# %%
# Use .groupby() to find item/bottle count .sum() for each state
total_bottles =
